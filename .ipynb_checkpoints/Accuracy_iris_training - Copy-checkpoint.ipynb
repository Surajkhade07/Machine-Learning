# %%
import pandas as pd

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
data=pd.read_excel("iris-train Dataset.xlsx")

# %%
data.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth       flower
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepallength  133 non-null    float64
#  1   sepalwidth   133 non-null    float64
#  2   petallength  133 non-null    float64
#  3   petalwidth   133 non-null    float64
#  4   flower       133 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB

# %%
x=data.iloc[:,:-1]

# %%
y=data.iloc[:,-1]

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x.values,y.values)
# Out:
# DecisionTreeClassifier()

# %%
prediction=model.predict([[5.7	,2.5 ,5	,2
]])

# %%
prediction
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
prediction=model.predict([[5.7	,2.6	,3.5	,1
]])

# %%
prediction
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
prediction=model.predict([[5.8	,4	,1.2	,0.2
]])

# %%
prediction
# Out:
# array(['Iris-setosa'], dtype=object)
